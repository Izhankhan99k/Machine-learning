# %% [markdown]
# <a href="https://colab.research.google.com/github/Izhankhan99k/Machine-learning/blob/main/perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %%
X,y=make_classification(n_samples=100,n_features=2,n_informative=2,n_redundant=0,n_classes=2,random_state=1)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
def step(z):
  return 1 if z>0 else 0

def perceptron(x,y):
  X=np.insert(x,0,1,axis=1)
  weights=np.ones(X.shape[1])
  for i in range(1000):
    j=np.random.randint(100)
    weights=weights-(y[j]-step(np.dot(weights,X[j])))*X[j]
  return weights[0:]

# %%
w=perceptron(X,y)

# %%
w
# Out:
# array([  52.        , -939.92653712,  155.92556342])
